# %%
import pandas as pd

# %%
# load file

file_to_load = ("Resources/ted_talks.csv")

#create new dataframe

ted_talks_df = pd.read_csv(file_to_load)
ted_talks_df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event  languages         main_speaker  \
# ...

# %%
min_views = ted_talks_df.min()
min_views
# Out:
# comments                                                        2
# description     "A forest is much more than what you see," say...
# duration                                                      135
# event                                               AORN Congress
# languages                                                       0
# main_speaker                                                OK Go
# name               AJ Jacobs: How healthy living nearly killed me
# title                        Hidden miracles of the natural world
# views                                                       50443
# dtype: object

# %%
ted_talks_df.max()
# Out:
# comments                                                     6404
# description     “People are so afraid of variety that they try...
# duration                                                     5256
# event                                      World Science Festival
# languages                                                      72
# main_speaker                                    iO Tillett Wright
# name                       iO Tillett Wright: Fifty shades of gay
# title                            “Am I dying?” The honest answer.
# views                                                    47227110
# dtype: object

# %%
# bin views in ted talks df

ted_talks_df(columns =["views"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b799be073a62> in <module>
#       1 # bin views in ted talks df
#       2
# ----> 3 bindf = ted_talks_df(columns =["views"])
#
# TypeError: 'DataFrame' object is not callable
